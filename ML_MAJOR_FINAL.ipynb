# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = "D:\Data_Train.csv" 
data = pd.read_csv(path)
data.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# # Checking how many unique cars are there

# %%
uniqueCars = data.Name.unique()

# %%
plt.rcParams["figure.figsize"] = [20,8]

# %%
uniqueCars.size
# Out:
# 1876

# %%
# checking null values

data.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %% [markdown]
# # Filled all null values of seats with number 2

# %%
data["Seats"].fillna(2, inplace = True)

# %% [markdown]
# # Checking null columns

# %%
data.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                 0
# Price                 0
# dtype: int64

# %% [markdown]
# # Removing CC from Engine column

# %%
cleanEngine = (data.Engine.str.split(' ').str[0])

# %%
cleanEngine
# Out:
# 0        998
# 1       1582
# 2       1199
# 3       1248
# 4       1968
# 5        814
# 6       1461
# 7       2755
# 8       1598
# 9       1248
# 10      1462
# 11      1497
# 12      1248
# 13      2179
# 14      2179
# 15      2477
# 16      1498
# 17      1248
# 18      1461
# 19      2143
# 20      1995
# 21      1248
# 22      1984
# 23      1197
# 24      1598
# 25      1497
# 26      1461
# 27       998
# 28      1199
# 29      2494
#         ...
# 5989    1968
# 5990    2179
# 5991    1248
# 5992    1798
# 5993    1797
# 5994    1497
# 5995    1461
# 5996    2179
# 5997     998
# 5998    1198
# 5999    1193
# 6000    1197
# 6001    1968
# 6002    1598
# 6003     998
# 6004    1341
# 6005    1248
# 6006    2987
# 6007    1248
# 6008    2967
# 6009    2494
# 6010    1198
# 6011    3597
# 6012    2494
# 6013    1498
# 6014    1248
# 6015    1120
# 6016    2498
# 6017     998
# 6018     936
# Name: Engine, Length: 6019, dtype: object

# %% [markdown]
# # adding a clean engine column in the dataset

# %%
data['cleanEngine'] = cleanEngine

# %%
data.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price cleanEngine
# 0   1.75         998
# 1  12.50        1582
# 2   4.50        1199
# 3   6.00        1248
# 4  17.74        1968

# %% [markdown]
# # Removing bhp from Power column

# %%
cleanPower = (data.Power.str.split(' ').str[0])

# %%
cleanPower
# Out:
# 0        58.16
# 1        126.2
# 2         88.7
# 3        88.76
# 4        140.8
# 5         55.2
# 6         63.1
# 7        171.5
# 8        103.6
# 9           74
# 10      103.25
# 11       116.3
# 12          74
# 13       187.7
# 14         115
# 15      175.56
# 16        98.6
# 17          74
# 18        83.8
# 19      167.62
# 20         190
# 21        88.5
# 22      177.01
# 23          80
# 24       103.6
# 25       116.3
# 26        63.1
# 27        67.1
# 28        88.7
# 29         102
#          ...
# 5989    187.74
# 5990       138
# 5991        74
# 5992    157.75
# 5993     147.5
# 5994       118
# 5995      83.8
# 5996     187.7
# 5997      58.2
# 5998      73.9
# 5999      88.7
# 6000     82.85
# 6001    174.33
# 6002     103.5
# 6003     67.04
# 6004        83
# 6005      88.5
# 6006    224.34
# 6007      73.9
# 6008       300
# 6009     158.2
# 6010      86.8
# 6011     262.6
# 6012       102
# 6013      98.6
# 6014        74
# 6015        71
# 6016       112
# 6017      67.1
# 6018      57.6
# Name: Power, Length: 6019, dtype: object

# %% [markdown]
# # adding a clean power column in the dataset

# %%
data['cleanPower'] = cleanPower

# %%
data.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price cleanEngine cleanPower
# 0   1.75         998      58.16
# 1  12.50        1582      126.2
# 2   4.50        1199       88.7
# 3   6.00        1248      88.76
# 4  17.74        1968      140.8

# %% [markdown]
# # Removing km/kg or kmpl from mileage column

# %%
cleanMileage = (data.Mileage.str.split(' ').str[0])

# %%
cleanMileage
# Out:
# 0        26.6
# 1       19.67
# 2        18.2
# 3       20.77
# 4        15.2
# 5        21.1
# 6       23.08
# 7       11.36
# 8       20.54
# 9        22.3
# 10      21.56
# 11       16.8
# 12       25.2
# 13       12.7
# 14        0.0
# 15       13.5
# 16       25.8
# 17       28.4
# 18      20.45
# 19      14.84
# 20      22.69
# 21      23.65
# 22      13.53
# 23       18.5
# 24       14.4
# 25       16.8
# 26      23.08
# 27      20.92
# 28       17.5
# 29       12.8
#         ...
# 5989    18.25
# 5990    13.93
# 5991     22.9
# 5992     13.7
# 5993     16.3
# 5994     17.0
# 5995    19.87
# 5996    16.36
# 5997     26.2
# 5998    17.24
# 5999    17.57
# 6000     18.5
# 6001    17.68
# 6002    16.09
# 6003     23.1
# 6004     15.3
# 6005     24.3
# 6006      8.7
# 6007     19.3
# 6008    17.85
# 6009    19.16
# 6010     18.5
# 6011      0.0
# 6012     12.8
# 6013     25.8
# 6014     28.4
# 6015     24.4
# 6016     14.0
# 6017     18.9
# 6018    25.44
# Name: Mileage, Length: 6019, dtype: object

# %% [markdown]
# # adding a clean power mileage in the dataset

# %%
data['cleanMileage'] = cleanMileage

# %%
data.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price cleanEngine cleanPower cleanMileage
# 0   1.75         998      58.16         26.6
# 1  12.50        1582      126.2        19.67
# 2   4.50        1199       88.7         18.2
# 3   6.00        1248      88.76        20.77
# 4  17.74        1968      140.8         15.2

# %% [markdown]
# # Checking data type of all columns

# %%
data.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# cleanEngine           object
# cleanPower            object
# cleanMileage          object
# dtype: object

# %% [markdown]
# # Changing data type of cleanMileage and cleanEngine column from object to    numeric

# %%
data["cleanMileage"] = pd.to_numeric(data["cleanMileage"])

data["cleanEngine"] = pd.to_numeric(data["cleanEngine"])

# %%
data.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# cleanEngine          float64
# cleanPower            object
# cleanMileage         float64
# dtype: object

# %% [markdown]
# # Replacing "null" values in Power column with 0.0

# %%
data["cleanPower"].replace({"null": "0.0",}, inplace=True)

# %% [markdown]
# # Changing data type of cleanPower column from object to numeric

# %%
data["cleanPower"] = pd.to_numeric(data["cleanPower"])

# %%
data.head(10)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# 5       LPG       Manual      First  21.1 km/kg   814 CC   55.2 bhp    5.0
# 6    Diesel       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0
# 7    Diesel    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp    8.0
# 8    Diesel       Manual      First  20.54 kmpl  1598 CC  103.6 bhp    5.0
# 9    Diesel       Manual     Second   22.3 kmpl  1248 CC     74 bhp    5.0
#
#    Price  cleanEngine  cleanPower  cleanMileage
# 0   1.75        998.0       58.16         26.60
# 1  12.50       1582.0      126.20         19.67
# 2   4.50       1199.0       88.70         18.20
# 3   6.00       1248.0       88.76         20.77
# 4  17.74       1968.0      140.80         15.20
# 5   2.35        814.0       55.20         21.10
# 6   3.50       1461.0       63.10         23.08
# 7  17.50       2755.0      171.50         11.36
# 8   5.20       1598.0      103.60         20.54
# 9   1.95       1248.0       74.00         22.30

# %% [markdown]
# # Getting average value of each column

# %%
data.mean(axis=0)
# Out:
# Year                  2013.358199
# Kilometers_Driven    58738.380296
# Seats                    5.255856
# Price                    9.479468
# cleanEngine           1621.276450
# cleanPower             111.227632
# cleanMileage            18.134961
# dtype: float64

# %% [markdown]
# # Calculating number of null values in each column

# %%
data.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                 0
# Price                 0
# cleanEngine          36
# cleanPower           36
# cleanMileage          2
# dtype: int64

# %% [markdown]
# # filling null values of cleanEngine column

# %%
data["cleanEngine"].fillna(1621.276, inplace = True)

# %% [markdown]
# # filling null values of cleanMileage column

# %%
data["cleanMileage"].fillna(18.134, inplace = True)

# %% [markdown]
# # filling null or zero values of cleanPower column

# %%
data["cleanPower"].replace({0.0: 111.227,}, inplace=True)

# %%
data["cleanPower"].fillna(111.227, inplace = True)

# %% [markdown]
# # Again checking number of null value in each column

# %%
data.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                 0
# Price                 0
# cleanEngine           0
# cleanPower            0
# cleanMileage          0
# dtype: int64

# %% [markdown]
# # cleaning name of cars

# %% [markdown]
# # 1. By car company

# %%
carCompany = (data.Name.str.split(' ').str[0])

# %% [markdown]
# # Adding carCompany column in the dataset

# %%
data['carCompany'] = carCompany

# %% [markdown]
# # Checking unique car companys in the dataset

# %%
uniqueCarCompany = data.carCompany.unique()

# %%
uniqueCarCompany.size
# Out:
# 31

# %%
data.head(10)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# 5       LPG       Manual      First  21.1 km/kg   814 CC   55.2 bhp    5.0
# 6    Diesel       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0
# 7    Diesel    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp    8.0
# 8    Diesel       Manual      First  20.54 kmpl  1598 CC  103.6 bhp    5.0
# 9    Diesel       Manual     Second   22.3 kmpl  1248 CC     74 bhp    5.0
#
#    Price  cleanEngine  cleanPower  cleanMileage  carCompany
# 0   1.75        998.0       58.16         26.60      Maruti
# 1  12.50       1582.0      126.20         19.67     Hyundai
# 2   4.50       1199.0       88.70         18.20       Honda
# 3   6.00       1248.0       88.76         20.77      Maruti
# 4  17.74       1968.0      140.80         15.20        Audi
# 5   2.35        814.0       55.20         21.10     Hyundai
# 6   3.50       1461.0       63.10         23.08      Nissan
# 7  17.50       2755.0      171.50         11.36      Toyota
# 8   5.20       1598.0      103.60         20.54  Volkswagen
# 9   1.95       1248.0       74.00         22.30        Tata

# %% [markdown]
# # 2. By car model

# %%
carModel = (data.Name.str.split(' ').str[1:])

# %%
carModel
# Out:
# 0                             [Wagon, R, LXI, CNG]
# 1                   [Creta, 1.6, CRDi, SX, Option]
# 2                                        [Jazz, V]
# 3                                    [Ertiga, VDI]
# 4                 [A4, New, 2.0, TDI, Multitronic]
# 5                    [EON, LPG, Era, Plus, Option]
# 6                              [Micra, Diesel, XV]
# 7                [Innova, Crysta, 2.8, GX, AT, 8S]
# 8                     [Vento, Diesel, Comfortline]
# 9                   [Indica, Vista, Quadrajet, LS]
# 10                                    [Ciaz, Zeta]
# 11                     [City, 1.5, V, AT, Sunroof]
# 12                              [Swift, VDI, BSIV]
# 13               [Rover, Range, Rover, 2.2L, Pure]
# 14                 [Rover, Freelander, 2, TD4, SE]
# 15                            [Pajero, Sport, 4X4]
# 16                             [Amaze, S, i-Dtech]
# 17                              [Swift, DDiS, VDI]
# 18               [Duster, 85PS, Diesel, RxL, Plus]
# 19      [New, C-Class, C, 220, CDI, BE, Avantgare]
# 20                               [3, Series, 320d]
# 21                    [S, Cross, DDiS, 200, Alpha]
# 22           [A6, 2011-2015, 35, TFSI, Technology]
# 23                               [i20, 1.2, Magna]
# 24                   [Vento, Petrol, Highline, AT]
# 25                      [City, Corporate, Edition]
# 26                             [Micra, Diesel, XV]
# 27                     [Alto, K10, 2010-2014, VXI]
# 28                               [WRV, i-VTEC, VX]
# 29              [Innova, 2.5, V, Diesel, 7-seater]
#                            ...
# 5989                  [A4, 35, TDI, Premium, Plus]
# 5990            [New, Safari, DICOR, 2.2, VX, 4x2]
# 5991                                  [Swift, VDI]
# 5992              [Superb, Elegance, 1.8, TSI, AT]
# 5993                                 [Elantra, SX]
# 5994                            [City, 1.5, E, MT]
# 5995          [Duster, 85PS, Diesel, RxL, Explore]
# 5996                      [XF, 2.2, Litre, Luxury]
# 5997                          [Wagon, R, Duo, Lxi]
# 5998        [Polo, IPL, II, 1.2, Petrol, Highline]
# 5999                          [Bolt, Revotron, XT]
# 6000                            [i20, Sportz, 1.2]
# 6001                     [A6, 2011-2015, 2.0, TDI]
# 6002                        [Vento, 1.6, Highline]
# 6003                                [Celerio, VXI]
# 6004                                   [Getz, GLE]
# 6005                         [Vitara, Brezza, VDi]
# 6006                       [M-Class, ML, 320, CDI]
# 6007                     [Swift, Dzire, Vdi, BSIV]
# 6008                            [Panamera, Diesel]
# 6009                               [Camry, Hybrid]
# 6010                           [Brio, 1.2, VX, MT]
# 6011                        [Superb, 3.6, V6, FSI]
# 6012            [Innova, 2.5, V, Diesel, 7-seater]
# 6013                           [Amaze, VX, i-DTEC]
# 6014                                  [Swift, VDI]
# 6015                         [Xcent, 1.1, CRDi, S]
# 6016                              [Xylo, D4, BSIV]
# 6017                               [Wagon, R, VXI]
# 6018                                [Beat, Diesel]
# Name: Name, Length: 6019, dtype: object

# %% [markdown]
# # Combining elements of each list to form the meaningful car model name

# %%
Model = []

for items in carModel:
    tempstr = ""
    for i in range(0,len(items)):
        if(i == 0):
                   tempstr = tempstr + items[i]
        else:
                   tempstr = tempstr + " " + items[i]
        
    Model.append(tempstr)

# %%
Model
# Out:
# ['Wagon R LXI CNG',
#  'Creta 1.6 CRDi SX Option',
#  'Jazz V',
#  'Ertiga VDI',
#  'A4 New 2.0 TDI Multitronic',
#  'EON LPG Era Plus Option',
#  'Micra Diesel XV',
#  'Innova Crysta 2.8 GX AT 8S',
#  'Vento Diesel Comfortline',
#  'Indica Vista Quadrajet LS',
#  'Ciaz Zeta',
#  'City 1.5 V AT Sunroof',
#  'Swift VDI BSIV',
#  'Rover Range Rover 2.2L Pure',
#  'Rover Freelander 2 TD4 SE',
#  'Pajero Sport 4X4',
#  'Amaze S i-Dtech',
#  'Swift DDiS VDI',
#  'Duster 85PS Diesel RxL Plus',
#  'New C-Class C 220 CDI BE Avantgare',
#  '3 Series 320d',
#  'S Cross DDiS 200 Alpha',
#  'A6 2011-2015 35 TFSI Technology',
#  'i20 1.2 Magna',
#  'Vento Petrol Highline AT',
#  'City Corporate Edition',
#  'Micra Diesel XV',
#  'Alto K10 2010-2014 VXI',
#  'WRV i-VTEC VX',
#  'Innova 2.5 V Diesel 7-seater',
#  'Duster 110PS Diesel RxZ Pack',
#  'Corolla Altis G',
#  'Ssangyong Rexton RX7',
#  'A6 2.7 TDI',
#  'Vento 1.6 Highline',
#  'Wagon R LXI BSIII',
#  'Vitara Brezza ZDi Plus',
#  'KUV 100 mFALCON G80 K6 5str AW',
#  'M-Class ML 350 CDI',
#  'Polo Diesel Trendline 1.2L',
#  'Alto LXi',
#  'Nano LX SE',
#  'KUV 100 mFALCON D75 K8 Dual Tone',
#  'i20 Magna Optional 1.2',
#  'Elantra 2.0 SX Option AT',
#  'Corolla Altis G AT',
#  'Elantra CRDi',
#  'Innova Crysta 2.7 GX MT',
#  'Xcent 1.1 CRDi S',
#  'Thar CRDe AC',
#  'A4 2.0 TDI 177 Bhp Premium Plus',
#  'Swift LDI',
#  'Swift Ldi BSIV',
#  'Swift VDI',
#  'Grand i10 Sportz',
#  'Vento 2013-2015 1.6 Comfortline',
#  'KWID RXT',
#  'i10 Asta',
#  'X-Trail SLX AT',
#  'Zen Estilo VXI BSIII',
#  'Innova Crysta 2.4 GX MT 8S',
#  'Figo Diesel Titanium',
#  'New C-Class C 200 CGI Avantgarde',
#  'New C-Class 200 CDI Classic',
#  'Indica V2 eLS',
#  'A4 2.0 TDI Multitronic',
#  'City ZX CVT',
#  'C-Class Progressive C 220d',
#  'Ertiga SHVS VDI',
#  'Creta 1.4 E Plus Diesel',
#  'Cayenne 2009-2014 Turbo',
#  'XUV500 W8 4WD',
#  'i10 Sportz 1.2 AT',
#  'Terrano XV D Pre',
#  'Brio VX AT',
#  'A6 2.0 TDI Design Edition',
#  'Fiesta 1.4 SXi TDCi',
#  'Innova 2.0 G1',
#  'Innova 2.5 VX 7 STR BSIV',
#  'Santro Xing XL',
#  'Swift VDI',
#  'Zest Revotron 1.2T XE',
#  'Amaze SX i-VTEC',
#  'Figo Diesel ZXI',
#  'Ritz VDi',
#  'City i VTEC E',
#  '5 Series 2003-2012 525d',
#  'i10 Sportz 1.2',
#  'Grand i10 Sportz',
#  'Santro Xing XO',
#  'Amaze SX i-VTEC',
#  'Fortuner 4x2 Manual',
#  'A6 2011-2015 35 TDI Premium',
#  'Ecosport 1.5 DV5 MT Titanium Optional',
#  'XUV500 W8 2WD',
#  'Amaze SX i-DTEC',
#  'Polo Diesel Highline 1.2L',
#  'Verna Transform SX VGT CRDi',
#  'Wagon R VXI BS IV',
#  'Polo Petrol Highline 1.6L',
#  'i20 1.4 CRDi Sportz',
#  'i20 Asta 1.2',
#  'GO Plus T Petrol',
#  'A4 3.0 TDI Quattro Premium',
#  'i20 2015-2017 Asta',
#  'Omni 5 Str STD',
#  'Etios Liva 1.2 G',
#  'XF 3.0 Litre S Premium Luxury',
#  'XUV500 W8 2WD',
#  'Verna 1.6 SX CRDI (O) AT',
#  'Innova Crysta 2.8 ZX AT',
#  'Eeco 5 Seater AC',
#  'Nano Twist XT',
#  '3 Series 320d Luxury Line',
#  'Civic 2006-2010 1.8 V MT',
#  'Innova 2.5 VX (Diesel) 7 Seater',
#  'V40 Cross Country D3',
#  'Micra XV CVT',
#  '5 Series 2010-2013 525i',
#  'Vitara Brezza VDi',
#  'Santro Xing XL eRLX Euro III',
#  'B Class B200 CDI',
#  'Verna CRDi 1.6 SX Option',
#  'Wagon R LXI BS IV',
#  'Nano XTA',
#  'Scorpio VLX',
#  'New C-Class 200 K AT',
#  'Wagon R LXI CNG',
#  'CR-V 2.4 MT',
#  'Vento 1.5 TDI Comfortline AT',
#  'Ciaz VXi Plus',
#  'XUV500 AT W10 FWD',
#  'Ritz VXI ABS',
#  'Alto K10 VXI',
#  'SLC 43 AMG',
#  'Verna VTVT 1.6 AT SX Plus',
#  'Alto LXi BSIII',
#  '1 Series 118d Base',
#  'Jazz 1.2 V CVT i VTEC',
#  'Civic 2006-2010 1.8 V MT',
#  'New C-Class C 220 CDI Avantgarde',
#  'Amaze SX i-DTEC',
#  'Swift VVT VXI',
#  'Santro Xing XO eRLX Euro II',
#  'Fortuner 3.0 Diesel',
#  'Beat LT Option',
#  'Rapid 1.5 TDI Elegance',
#  'Ciaz 1.4 Alpha',
#  'RS5 Coupe',
#  '3 Series Luxury Line',
#  'A4 2.0 TDI 177 Bhp Premium Plus',
#  'Swift VDI',
#  'S Class 2005 2013 S 500',
#  'Rapid 1.5 TDI AT Elegance Plus Black Package',
#  'Superb Elegance 2.0 TDI CR AT',
#  'EON Magna Plus',
#  'Polo Diesel Trendline 1.2L',
#  'GO NXT',
#  'Brio S MT',
#  'B Class B180',
#  'City i DTEC V',
#  'Innova 2.5 G (Diesel) 7 Seater',
#  'Swift VXI Optional',
#  'XUV500 W8 2WD',
#  'Ecosport 1.5 DV5 MT Ambiente',
#  'Fortuner 4x2 Manual',
#  'Vento 1.5 Highline Plus AT 16 Alloy',
#  'Figo Diesel Titanium',
#  'X5 xDrive 30d',
#  'New C-Class C 220 CDI Style',
#  'Brio V MT',
#  'i10 Magna 1.2',
#  'GLC 220',
#  'Grand i10 1.2 Kappa Asta',
#  'A6 2011-2015 2.0 TDI Premium Plus',
#  'Vento Petrol Highline AT',
#  'Countryman Cooper D',
#  'i20 Asta 1.4 CRDi',
#  'A6 2011-2015 2.0 TDI Premium Plus',
#  'Beat Diesel LT',
#  'Superb Elegance 1.8 TSI AT',
#  'Fiesta 1.4 TDCi EXI Limited Edition',
#  '5 Series 520d Luxury Line',
#  'Optra Magnum 1.6 LS BS3',
#  'Polo Diesel Highline 1.2L',
#  'Lodgy 110PS RxZ 8 Seater',
#  'E-Class E250 CDI Avantgrade',
#  'Baleno Alpha',
#  'Verna 1.6 SX',
#  'i10 Magna 1.1',
#  'Scorpio 1.99 S10 4WD',
#  'Rover Range Rover 2.2L Dynamic',
#  'Figo Diesel ZXI',
#  'Ertiga ZDI',
#  'City 1.5 GXI',
#  'Amaze S i-Dtech',
#  'i10 Magna',
#  'Amaze S i-Dtech',
#  'Laura Ambiente',
#  'Duster 85PS Diesel RxL',
#  'NuvoSport N6',
#  'Vitara Brezza ZDi Plus Dual Tone',
#  'i20 Asta Option 1.2',
#  'Fabia 1.4 MPI Ambiente',
#  'Indigo eCS GLX',
#  'Q3 2012-2015 35 TDI Quattro Premium Plus',
#  'Octavia Elegance 1.8 TSI AT',
#  'Etios Liva GD SP',
#  'Swift 1.3 VXi',
#  'B Class B180',
#  'Amaze S Diesel',
#  'Verna 1.6 SX',
#  'Duster 85PS Diesel RxL Optional',
#  'Creta 1.6 VTVT S',
#  'Wagon R AMT VXI',
#  'New C-Class C250 Avantgarde',
#  'A8 L 3.0 TDI quattro',
#  'i10 Magna 1.1',
#  'Rapid 1.6 MPI AT Style Black Package',
#  'Superb Style 1.8 TSI AT',
#  'i20 Active 1.2 SX',
#  'Amaze VX i-DTEC',
#  'Wagon R LXI',
#  'Verito 1.5 D4 BSIV',
#  'New C-Class C 220d Avantgarde Edition C',
#  'Wagon R VXI',
#  'Terrano XV Premium 110 PS Anniversary Edition',
#  'Swift VDI BSIV',
#  'Cooper Convertible S',
#  'Figo Diesel',
#  'Indica V2 DLS BSII',
#  'Beat LT',
#  'Polo Diesel Comfortline 1.2L',
#  'Swift ZDi',
#  'Figo Diesel EXI',
#  'Innova Crysta 2.8 GX AT',
#  'Santa Fe 4x4 AT',
#  'City i-VTEC V',
#  'i20 1.2 Magna Executive',
#  'New C-Class C 220d Avantgarde Edition C',
#  'Beat Diesel LT',
#  'i20 Sportz 1.4 CRDi',
#  'Innova 2.5 Z Diesel 7 Seater',
#  'Ertiga VDI',
#  'Innova 2.5 V Diesel 7-seater',
#  'Santro Xing XO eRLX Euro II',
#  'City i VTEC V',
#  'X1 sDrive20d',
#  'Grand i10 CRDi Era',
#  'Ciaz 1.3 Alpha',
#  'Rapid Leisure 1.6 TDI MT',
#  'Accent CRDi',
#  'Polo GT 1.5 TDI',
#  'Jazz 1.2 VX i VTEC',
#  'i10 Era',
#  'Tucson 2.0 e-VGT 2WD AT GLS',
#  'Innova Crysta 2.4 ZX MT',
#  'Omni MPI CARGO BSIII W/ IMMOBILISER',
#  'Swift VXI BSIV',
#  'Grand i10 Magna',
#  'Swift VDI',
#  'Verna CRDi 1.6 SX',
#  'Santro Xing XL',
#  'i20 1.2 Sportz',
#  'GLE 350d',
#  'New C-Class C 220 CDI CLASSIC',
#  'Ritz ZDi',
#  'Creta 1.6 CRDi SX',
#  'A-Star Vxi',
#  'Duster 110PS Diesel RXZ Option',
#  'Grande Punto 1.3 Emotion Pack (Diesel)',
#  'X3 xDrive30d M Sport',
#  'i10 Sportz',
#  'Innova 2.5 G4 Diesel 7-seater',
#  'Zen VXI BSII',
#  'Swift VDI',
#  'Scorpio VLX 2.2 mHawk Airbag BSIV',
#  'Zest Quadrajet 1.3 75PS XE',
#  'EcoSport 1.0 Ecoboost Titanium Plus',
#  'Swift Dzire ZDI',
#  'Alto 800 LXI',
#  'City 1.5 S MT',
#  'Q7 3.0 TDI Quattro Technology',
#  'Laura 1.9 TDI AT Ambiente',
#  'Verna 1.6 SX VTVT (O)',
#  'City 1.5 V AT',
#  'i20 Magna Optional 1.4 CRDi',
#  'i20 Sportz AT 1.4',
#  'Vento Diesel Highline',
#  'City i VTEC VX',
#  'Zest Quadrajet 1.3 75PS XE',
#  '5 Series 2003-2012 520d',
#  'Wagon R LXI Minor',
#  'Jazz VX',
#  'Jetta 2007-2011 2.0 TDI Comfortline',
#  'i10 Magna 1.2',
#  'New C-Class C 220 CDI Avantgarde',
#  'i10 Magna 1.2 iTech SE',
#  'Innova Crysta 2.4 ZX MT',
#  'A6 2011-2015 2.0 TDI Technology',
#  'Innova 2.5 VX (Diesel) 7 Seater',
#  'Polo Petrol Trendline 1.2L',
#  'Alto K10 LXI',
#  'City i-VTEC CVT ZX',
#  'Indigo LX',
#  'A6 2011-2015 2.0 TDI Premium Plus',
#  'GLA Class 200 CDI SPORT',
#  'Santro Xing XL',
#  'Swift VDI BSIV',
#  'Celerio VXI AT',
#  'GLE 250d',
#  'Rover Range Rover HSE Dynamic',
#  'Vento Diesel Trendline',
#  'Omni 8 Seater BSIV',
#  'Brio 1.2 VX MT',
#  'Sumo Delux',
#  'Indica Vista Aura 1.3 Quadrajet',
#  'Wagon R LXI BS IV',
#  'XUV500 W8 4WD',
#  'Indigo LS Dicor',
#  'Ertiga Paseo VXI',
#  'Accord 2.4 A/T',
#  'Swift Dzire VDi',
#  'Fiesta EXi 1.4 TDCi Ltd',
#  'City ZX GXi',
#  'A6 2011-2015 2.0 TDI Premium Plus',
#  '6 Series 640d Gran Coupe',
#  'Q7 45 TDI Quattro Technology',
#  'Zen Estilo LXI Green (CNG)',
#  'i20 1.4 CRDi Asta',
#  'i10 Sportz AT',
#  'Jazz 1.2 V CVT i VTEC',
#  'Swift VDI BSIV',
#  'i20 Asta 1.2',
#  'Polo Petrol Comfortline 1.2L',
#  'Alto LXi',
#  'Corolla H4',
#  'Alto LXi',
#  'Manza ELAN Quadrajet BS IV',
#  'Alto LXi',
#  'Octavia Ambition Plus 2.0 TDI AT',
#  'Corolla H4',
#  'i20 Asta Option 1.2',
#  'Vitara Brezza LDi',
#  'City 1.5 V MT',
#  'Indica Vista Aqua 1.3 Quadrajet',
#  'Amaze S i-Dtech',
#  'EON D Lite Plus',
#  '3 Series Luxury Line',
#  'Verna 1.6 SX',
#  'Manza Club Class Quadrajet90 LS',
#  'Octavia RS',
#  'Alto K10 VXI',
#  'Ecosport 1.5 DV5 MT Titanium Optional',
#  'Spark 1.0 LS',
#  'XF 2.0 Diesel Portfolio',
#  'CR-V RVi MT',
#  'Superb L&K 1.8 TSI AT',
#  'i10 Magna 1.2',
#  'Swift LDI',
#  'Swift Dzire VXi AT',
#  'Micra Diesel XV',
#  'Swift Dzire Tour LDI',
#  'Fiesta Classic 1.4 Duratorq CLXI',
#  'Zen LX',
#  'Clubman Cooper S',
#  'Etios GD',
#  'Alto 800 2016-2019 LXI',
#  'Alto VXi',
#  'X5 3.0d',
#  'Teana XV',
#  'Grand i10 AT Asta',
#  'Vitara Brezza ZDi Plus',
#  'Q7 3.0 TDI Quattro Premium Plus',
#  'GLA Class 200 CDI',
#  '800 AC',
#  'Duster 85PS Diesel RxL',
#  'Corolla Altis D-4D GL',
#  'New C-Class 220',
#  'Ritz VDi',
#  'BRV i-VTEC V CVT',
#  'Xcent 1.1 CRDi Base',
#  'E-Class 2009-2013 E250 CDI Avantgarde',
#  'B Class B180',
#  'E-Class 2015-2017 E250 Edition E',
#  'City i VTEC VX Option',
#  'Santro Xing XL eRLX Euro III',
#  'City 1.5 S MT',
#  'Verna Transform VTVT',
#  'XE Portfolio',
#  'Amaze S i-Vtech',
#  'Cooper Convertible 1.6',
#  'S Class 2005 2013 S 350 CDI',
#  'EON Magna Plus',
#  'Wagon R VXI BS IV',
#  'Ritz LDi',
#  '3 Series 320d Sedan',
#  'Xenon XT EX 4X2',
#  'A3 35 TDI Attraction',
#  'Rover Range Rover 2.2L Dynamic',
#  'GL-Class 2007 2012 350 CDI Luxury',
#  'Pajero Sport 4X2 AT DualTone BlackTop',
#  'Alto LX',
#  'Wagon R LXI BSIII',
#  'Rover Range Rover 2.2L Prestige',
#  'Verna 1.6 SX VTVT',
#  '5 Series 525d Sedan',
#  'XF Diesel',
#  'Superb Elegance 1.8 TSI AT',
#  'Q3 35 TDI Quattro Premium',
#  'Rover Range Rover 2.2L Pure',
#  'New C-Class 220 CDI AT',
#  'Scorpio S10 4WD',
#  '3 Series Luxury Line',
#  'BR-V i-VTEC S MT',
#  'S80 2006-2013 D5',
#  'Accent GLE',
#  'i20 Active SX Petrol',
#  'GLC 43 AMG Coupe',
#  'EON Magna Plus',
#  'Grand i10 SportZ Edition',
#  'City 1.5 EXI S',
#  'Polo Petrol Trendline 1.2L',
#  'A6 35 TFSI Matrix',
#  'Jetta 2007-2011 1.9 L TDI',
#  'Creta 1.6 SX Plus Dual Tone Petrol',
#  'New C-Class C 200 CGI Avantgarde',
#  'Cooper Convertible S',
#  'Santro Xing XO eRLX Euro II',
#  'Etios VD',
#  'Brio S MT',
#  'Baleno Alpha Automatic',
#  'Laura Ambiente 2.0 TDI CR AT',
#  'EON Era Plus',
#  'Captur 1.5 Diesel RXL',
#  '5 Series 2003-2012 GT 530d LE',
#  'Alto 800 LXI',
#  'V40 D3',
#  'Wagon R LXI BSII',
#  'City ZX GXi',
#  'Eeco 5 STR With AC Plus HTR CNG',
#  'Enjoy 1.4 LS 8',
#  'Bolero ZLX',
#  'Santro GLS I - Euro I',
#  'EON D Lite',
#  'Creta 1.6 SX Plus Petrol Automatic',
#  'Vento 1.6 Comfortline',
#  'Civic 2006-2010 1.8 S AT',
#  'Indica Vista Quadrajet LS',
#  'XUV500 W8 2WD',
#  'i20 1.2 Asta Option',
#  'Q5 30 TDI quattro Premium Plus',
#  'Ritz VXi',
#  'Cedia Sports',
#  'Innova 2.5 V Diesel 7-seater',
#  'Celerio LDi',
#  'S-Cross Delta DDiS 200 SH',
#  'Q3 35 TDI Quattro Premium Plus',
#  '3 Series Luxury Line',
#  'Q7 4.2 TDI Quattro Technology',
#  'i20 2015-2017 Asta 1.2',
#  'Duster 110PS Diesel RxL',
#  'Xcent 1.1 CRDi S Celebration Edition',
#  'Ecosport 1.5 DV5 MT Titanium',
#  'Polo Petrol Trendline 1.2L',
#  'Grand i10 CRDi Magna',
#  'Manza Aqua Quadrajet BS IV',
#  'City 1.5 V MT',
#  'Santro Xing GLS',
#  'Innova 2.5 VX (Diesel) 7 Seater',
#  'Ciaz 1.3 S',
#  'Fortuner 4x4 MT TRD Sportivo',
#  'Fiesta 1.6 SXI ABS Duratec',
#  'E-Class E 220 d',
#  'New C-Class 220 CDI MT',
#  'Yeti Ambition 4X2',
#  'Grand i10 Sportz',
#  'Figo 2015-2019 1.2P Titanium MT',
#  'Octavia Ambition 1.4 TSI MT',
#  'Duster 85PS Diesel RxL Option',
#  'Rover Range Rover Evoque 2.0 TD4 Pure',
#  'Figo Diesel EXI',
#  'Endeavour Hurricane Limited Edition',
#  'Fortuner 4x4 MT',
#  'Polo Diesel Comfortline 1.2L',
#  'Ritz VDi',
#  'Micra Diesel XV Premium',
#  'Verna 1.6 SX',
#  '5 Series 2003-2012 523i',
#  'GLS 350d 4MATIC',
#  'CR-V 2.4L 4WD AT',
#  'Creta 1.6 CRDi AT SX Plus',
#  'i10 Era',
#  'A Class A200 CDI Sport',
#  'Ertiga VXI',
#  'Octavia Classic 1.9 TDI MT',
#  'Amaze VX i-Vtech',
#  'Zen LXi BSII',
#  'SX4 ZXI MT BSIV',
#  'Brio VX AT',
#  'Wagon R VXI',
#  'Camry A/T',
#  'Beat LS',
#  'Fortuner 4x4 AT',
#  'Ecosport 1.5 DV5 MT Titanium Optional',
#  'Swift Vdi BSIII',
#  'S Class 2005 2013 S 350 CDI',
#  'Mobilio S i VTEC',
#  'Grand i10 Sportz',
#  'XUV500 AT W8 FWD',
#  'Fabia 1.6 MPI Elegance',
#  'Santro Xing GLS',
#  'Creta 1.6 SX Plus Dual Tone Petrol',
#  'Scorpio 1.99 S8',
#  'Rapid 1.6 TDI Ambition',
#  'Duster 110PS Diesel RxZ',
#  'X5 xDrive 30d',
#  'Etios G',
#  'Wagon R LXI',
#  'Creta 1.6 SX',
#  'Celerio VXI',
#  'Rover Range Rover HSE Dynamic',
#  'Beat LT',
#  'Nano Twist XT',
#  'A6 2011-2015 35 TDI Technology',
#  'E-Class 280 CDI',
#  'Swift VXI',
#  'Linea T Jet',
#  'Swift VXI Optional',
#  'Fortuner 3.0 Diesel',
#  'Ertiga ZXI',
#  '3 Series 320i Sedan',
#  'Ertiga VXI',
#  'City 1.5 V AT',
#  'Santa Fe 4X4',
#  'Indigo LS',
#  'E-Class 2009-2013 E 250 Elegance',
#  'Swift Dzire LDi',
#  'Fiesta Classic 1.4 Duratorq CLXI',
#  'City i VTEC CVT VX',
#  'Fortuner 4x2 Manual',
#  'Amaze VX O i VTEC',
#  'i20 Asta 1.4 CRDi',
#  'Enjoy TCDi LTZ 7 Seater',
#  'New C-Class Progressive C 200',
#  'SX4 ZXI AT Leather',
#  'Innova 2.5 VX (Diesel) 7 Seater',
#  '5 Series 2003-2012 520d',
#  'Duster 110PS Diesel RxZ',
#  'X1 sDrive 20d xLine',
#  'City ZX GXi',
#  'Ciaz RS ZDi Plus SHVS',
#  'Swift Dzire VXi',
#  'XUV500 W6 2WD',
#  'Civic 2006-2010 1.8 S MT',
#  'Ertiga ZDI',
#  'Etios Liva GD',
#  'TT 2.0 TFSI',
#  'Rapid 1.5 TDI Style',
#  'Polo 1.5 TDI Highline',
#  'Laura 1.9 TDI AT Elegance',
#  'Renault Logan 1.5 DLE Diesel',
#  'Innova Crysta 2.8 GX AT',
#  '3 Series 320d Luxury Line',
#  'Jazz 1.5 S i DTEC',
#  'Amaze VX i-DTEC',
#  'XF 2.2 Litre Luxury',
#  'Swift Dzire VDI',
#  'Compass 2.0 Limited',
#  'Corolla Altis 1.8 Sport',
#  'City 1.5 V MT',
#  'Swift ZXI',
#  'Verna 1.6 SX CRDI (O) AT',
#  'Bolero ZLX',
#  'Swift VDI',
#  'Santro Xing XO',
#  'A6 2011-2015 2.0 TDI Premium Plus',
#  'Ikon 1.3 LXi NXt',
#  'Polo 1.5 TDI Highline',
#  'Bolero VLX CRDe',
#  'City i DTEC VX Option',
#  'Sail Hatchback 1.2 LS',
#  'i20 1.2 Spotz',
#  'X1 sDrive 20d Sportline',
#  'X1 sDrive 20d Exclusive',
#  'Fortuner 4x2 AT',
#  'Q7 4.2 TDI Quattro Technology',
#  'Ertiga VDI',
#  'i20 1.2 Magna',
#  'S Class 2005 2013 S 350 L',
#  'Duster 85PS Diesel RxL',
#  'Quanto C2',
#  'Fortuner 4x2 AT',
#  'X5 2014-2019 xDrive 30d Design Pure Experience 7 Seater',
#  'Swift Dzire VDi',
#  'Swift LDI Optional',
#  'A6 2011-2015 35 TFSI Technology',
#  'Pajero 2.8 SFX BSIV Dual Tone',
#  'XF 2.2 Litre Executive',
#  'Innova Crysta 2.8 ZX AT',
#  'Octavia Ambition 2.0 TDI AT',
#  'Corolla Altis VL AT',
#  'Omni 8 Seater BSII',
#  'GLC 220d 4MATIC Style',
#  'Vento 1.5 TDI Highline AT',
#  'XUV500 W10 2WD',
#  'Terrano XL 85 PS',
#  'Verna 1.6 SX CRDi (O)',
#  '5 Series 2013-2017 530d M Sport',
#  'Scorpio S4 Plus',
#  'Verna 1.6 CRDi SX',
#  'Q7 3.0 TDI Quattro Premium Plus',
#  'Aveo U-VA 1.2 LT',
#  'Bolero ZLX BSIII',
#  'Xcent 1.2 Kappa S',
#  'Innova Crysta 2.4 GX MT 8S',
#  'EON Era Plus',
#  'Polo Diesel Comfortline 1.2L',
#  'Vitara Brezza ZDi',
#  '3 Series 320d Prestige',
#  'EON Sportz',
#  'City 1.5 S MT',
#  'Accord 2.4 MT',
#  'Xylo E8',
#  '3 Series 320d',
#  'City V MT',
#  'XUV500 W10 2WD',
#  'i20 Asta 1.4 CRDi',
#  'Fortuner 4x2 Manual',
#  'Bolero DI BSII',
#  'Esteem Vxi - BSIII',
#  'Santro LS zipPlus',
#  'Cooper 5 DOOR D',
#  'Q3 35 TDI Quattro Premium',
#  'i20 Sportz Option',
#  'Safari Storme VX Varicor 400',
#  'BR-V i-DTEC VX MT',
#  'Jetta 2013-2015 2.0L TDI Highline',
#  'Xcent 1.2 Kappa S Option',
#  'Ignis 1.2 Alpha',
#  '5 Series 2013-2017 520d Luxury Line',
#  'Ikon 1.3 CLXi',
#  'i10 Sportz',
#  'Verna 1.6 CRDI',
#  '3 Series 320d Highline',
#  'E-Class 2009-2013 E200 CGI Blue Efficiency',
#  'Beat Option Pack',
#  'Santro Xing XP',
#  'Indica DLS',
#  'XUV500 W8 2WD',
#  'Ciaz ZDi Plus SHVS',
#  'New C-Class C 250 CDI Avantgarde',
#  'City ZX CVT',
#  'Fortuner 4x2 4 Speed AT',
#  'Alto K10 VXI',
#  'XJ 2.0L Portfolio',
#  'i20 1.4 Magna ABS',
#  'BRV i-VTEC V CVT',
#  'Corolla Executive (HE)',
#  'A6 2011-2015 2.0 TDI Premium Plus',
#  'Innova 2.5 ZX Diesel 7 Seater BSIII',
#  'Grand i10 CRDi Sportz',
#  'Vento IPL II Petrol Highline AT',
#  'Innova 2.5 VX (Diesel) 7 Seater BS IV',
#  'Verna CRDi SX',
#  'Ritz VDi',
#  'Q7 3.0 TDI Quattro Technology',
#  'i20 Asta Option 1.2',
#  'Vitara Brezza ZDi Plus Dual Tone',
#  'City i VTEC S',
#  'Ciaz ZXi',
#  'Sunny XV CVT',
#  'Polo Diesel Highline 1.2L',
#  'Ertiga ZDI',
#  'Swift Dzire VDI',
#  'New C-Class C 220 CDI Elegance AT',
#  'Brio S MT',
#  'i10 Magna Optional 1.1L',
#  'Verna 1.6 SX CRDi (O)',
#  'Ciaz VDI SHVS',
#  'Ikon 1.3 Flair',
#  'Polo 1.2 MPI Highline',
#  'Jazz 1.2 V i VTEC',
#  'Amaze EX i-Dtech',
#  'i20 Asta 1.4 CRDi',
#  'Ritz VDi',
#  'City V MT',
#  'Superb 1.8 TSI MT',
#  'Vitara Brezza LDi Option',
#  'i20 Asta',
#  'Alto K10 VXI AGS',
#  'EON Era Plus',
#  'i10 Sportz',
#  'SLK-Class SLK 350',
#  'A6 2.0 TDI Design Edition',
#  'EcoSport 1.5 TDCi Titanium',
#  'Passat Highline DSG',
#  'Innova Crysta 2.4 ZX MT',
#  'Figo Diesel ZXI',
#  'Aveo 1.4',
#  'Ritz LXi',
#  'Rover Freelander 2 SE',
#  'Grand i10 Asta',
#  'Endeavour 3.2 Trend AT 4X4',
#  'Q5 2008-2012 2.0 TDI',
#  'Verna 1.6 VTVT',
#  'E-Class 2015-2017 E250 CDI Avantgarde',
#  'M-Class ML 350 4Matic',
#  'Swift Dzire ZXi',
#  'City 1.3 EXI S',
#  'Duster 85PS Diesel RxL Optional',
#  'New C-Class 220 CDI AT',
#  'X5 xDrive 30d Design Pure Experience 5 Seater',
#  'Xcent 1.2 Kappa SX Option',
#  'Dzire AMT ZXI Plus',
#  '3 Series 320d Corporate Edition',
#  'Alto 800 LXI',
#  'A4 2.0 TDI 177 Bhp Premium Plus',
#  'Cooper S',
#  'Q7 3.0 TDI Quattro Premium Plus',
#  'Beat Diesel LT',
#  'Wagon R LXI BS IV',
#  'Terrano XV Premium 110 PS',
#  '3 Series 320d Luxury Plus',
#  'Swift Dzire VXI',
#  'Yeti Elegance 4X2',
#  'EcoSport 1.5 Ti VCT AT Titanium',
#  'i20 1.2 Magna',
#  'S Cross DDiS 200 Sigma Option',
#  'Verna Transform VTVT',
#  '3 Series 320d Luxury Line',
#  'Grand i10 1.2 CRDi Magna',
#  'City i-VTEC V',
#  'Swift 1.3 VXi',
#  'Swift VDI BSIV',
#  'Baleno Zeta 1.3',
#  'Safari Storme 2012-2015 LX',
#  'Accent GLS',
#  'Swift LDI SP Limited Edition',
#  'Swift VDI BSIV',
#  'Nano XTA',
#  'Ertiga VDI',
#  'Celerio VXI AMT',
#  'Swift VDI BSIV',
#  'Vento Petrol Highline',
#  'Jetta 2007-2011 1.9 Highline TDI',
#  'Cooper 5 DOOR D',
#  'Indica V2 DLS',
#  'Santro Xing XO',
#  'Rover Range Rover 3.0 D',
#  'City i-VTEC CVT VX',
#  'XF 2.2 Litre Luxury',
#  'E-Class 2015-2017 E250 Edition E',
#  'Cruze LTZ',
#  'XUV500 W8 2WD',
#  'New C-Class C 200 CGI Avantgarde',
#  'Jazz VX',
#  'Etios G',
#  'Alto LXi BSIII',
#  'Swift VXI BSIV',
#  'A-Star Vxi',
#  'Nano Lx BSIV',
#  'Figo Titanium Diesel',
#  'Linea Emotion',
#  'Figo Aspire 1.2 Ti-VCT Trend',
#  'Baleno LXI',
#  '3 Series 320d Luxury Line',
#  'Cruze LTZ',
#  'Scorpio 2.6 DX',
#  'Indica V2 eLS',
#  'Cruze LTZ AT',
#  'Innova 2.5 V Diesel 8-seater',
#  'New C-Class C 220d Avantgarde Edition C',
#  'Ritz VXi',
#  'Innova 2.5 GX (Diesel) 8 Seater BS IV',
#  'Fortuner 4x4 MT',
#  'i10 Sportz AT',
#  'Verna 1.6 SX',
#  'Q3 2012-2015 35 TDI Quattro Premium Plus',
#  'Beat LS',
#  'Fiesta 1.4 Duratorq ZXI',
#  'Figo Diesel EXI',
#  'Celerio VXI AT',
#  'A Class A180 CDI',
#  'Creta 1.6 SX',
#  'Wagon R VXI BS IV',
#  'E-Class 2009-2013 E 220 CDI Avantgarde',
#  'EcoSport 1.5 Ti VCT MT Titanium BE',
#  'Koleos 2.0 Diesel',
#  'XUV500 W10 2WD',
#  'Omni E 8 Str STD',
#  'Wagon R VXI',
#  'Endeavour XLT TDCi 4X2',
#  'Verna 1.6 SX',
#  'i20 Magna 1.2',
#  'Ertiga ZXI',
#  'XUV500 W9 AT',
#  'SX4 S Cross DDiS 200 Zeta',
#  'SLK-Class SLK 350',
#  'Polo Diesel Comfortline 1.2L',
#  'Fortuner 4x4 MT',
#  'XUV500 W10 2WD',
#  'GLE 250d',
#  'Jazz 1.2 VX i VTEC',
#  'Swift Dzire VDI',
#  'Verna 1.6 SX VTVT',
#  'Endeavour 3.2 Titanium AT 4X4',
#  'i20 1.2 Asta Option',
#  'City 1.5 V MT Sunroof',
#  'Amaze VX Diesel',
#  'Verna 1.6 SX VTVT (O)',
#  'Mobilio S i DTEC',
#  'Ertiga ZDI',
#  'Alto K10 LXI',
#  'Qualis FS B2',
#  'i10 Sportz',
#  'Laura 1.9 TDI AT Ambiente',
#  'i20 Asta Option 1.2',
#  '5 Series 2003-2012 530d Highline',
#  '3 Series 320d M Sport',
#  'Aveo 1.4 LT ABS BSIV',
#  'E-Class 2009-2013 E250 CDI Elegance',
#  'A6 2011-2015 2.0 TDI Premium Plus',
#  'Wagon R LXI BS IV',
#  'KWID RXT',
#  'Ameo 1.5 TDI Highline',
#  'Polo Diesel Comfortline 1.2L',
#  'Alto 800 LXI',
#  'i20 Asta Option 1.2',
#  'Etios Liva G',
#  'i20 1.2 Sportz',
#  'i20 1.4 Asta',
#  'Wagon R LXI Optional',
#  'i20 1.4 Asta Option',
#  'Polo GT TSI',
#  'Figo Diesel Titanium',
#  'Swift ZXI',
#  'Grand i10 CRDi Magna',
#  'Xylo H4',
#  'Alto Green LXi (CNG)',
#  'i10 Magna 1.1',
#  'Octavia Elegance 2.0 TDI AT',
#  'X5 2014-2019 xDrive 30d Design Pure Experience 7 Seater',
#  'Celerio VXI AT',
#  'Vento Diesel Comfortline',
#  '3 Series 320d Highline',
#  'Ertiga ZDI',
#  'Figo Diesel ZXI',
#  'Polo 1.2 MPI Highline',
#  'A6 3.0 TDI quattro',
#  'Innova Crysta 2.4 ZX MT',
#  'Verna 1.6 CRDi EX AT',
#  'Santro Xing GL Plus',
#  'A4 2.0 TDI',
#  'A4 2.0 TDI',
#  'Laura 1.9 TDI MT Ambiente',
#  'CR-V 2.0L 2WD AT',
#  'Verna 1.6 SX CRDi (O)',
#  'Mobilio RS i DTEC',
#  'i20 1.2 Asta Option',
#  'Innova 2.5 G (Diesel) 7 Seater BS IV',
#  'i20 Magna 1.2',
#  'Bolero VLX BS IV',
#  'Vento 1.5 TDI Comfortline',
#  'XF 2.2 Litre Luxury',
#  'Zen LXi - BS III',
#  'E-Class Facelift',
#  'Fortuner 3.0 Diesel',
#  'Grand i10 AT Asta',
#  'Xcent 1.2 CRDi S',
#  'Creta 1.6 VTVT S',
#  'i10 Sportz',
#  'Brio S MT',
#  'Fortuner 4x2 AT',
#  'A4 2.0 TDI Multitronic',
#  'Innova Crysta 2.8 ZX AT',
#  'City i DTEC VX',
#  'City i DTEC VX',
#  'KWID 1.0 RXT Optional',
#  'Swift DDiS ZDI Plus',
#  'Celerio VXI Optional AMT',
#  'XUV500 W8 2WD',
#  'i10 Magna',
#  'i10 Magna 1.1',
#  'Dzire VXI',
#  'Grand Vitara AT',
#  'TT 40 TFSI',
#  'New C-Class C 200 CGI',
#  'Sunny 2011-2014 Diesel XV',
#  'Wagon R LXI',
#  'Swift Dzire ZDI',
#  'Amaze S i-Dtech',
#  'Swift ZDI',
#  'Accent Executive CNG',
#  'Scorpio LX 2.6 Turbo',
#  'E-Class E250 CDI Avantgrade',
#  'Fortuner 4x2 Manual',
#  'redi-GO T Option',
#  'City V MT',
#  'Camry Hybrid',
#  'City i DTec V',
#  'Jetta 2012-2014 2.0L TDI Trendline',
#  'A6 2011-2015 2.0 TDI',
#  'Ertiga VDI',
#  'New C-Class C 220 CDI Style',
#  'Swift Dzire Vdi BSIV',
#  'Duster 110PS Diesel RxZ Pack',
#  'Ritz VDi',
#  'Swift Dzire VXI',
#  'Swift ZDi',
#  'EON Sportz',
#  'Zen VXI BSII',
#  'Eeco 7 Seater Standard',
#  'Q5 30 TDI quattro Premium',
#  'Q3 2.0 TDI',
#  'Fortwo CDI AT',
#  'Swift Dzire VDi',
#  'Sumo DX',
#  'X5 2014-2019 xDrive 30d Design Pure Experience 7 Seater',
#  'City i-VTEC CVT VX',
#  'Indigo eCS eLX BS IV',
#  'Vento TSI',
#  'Celerio VXI',
#  'Fortuner 3.0 Diesel',
#  'Outlander 2.4',
#  'Jetta 2007-2011 1.9 Highline TDI',
#  'Cayman 2009-2012 S',
#  'Creta 1.6 CRDi SX',
#  'Fabia 1.2 MPI Ambiente Petrol',
#  'EcoSport 1.5 TDCi Titanium',
#  'Zen Estilo 1.1 LXI BSIII',
#  'Ciaz 1.4 Delta',
#  'New C-Class C 200 Avantgarde Edition C',
#  'Amaze SX i-VTEC',
#  'Etios GD',
#  'Duster 85PS Diesel RxL',
#  'Wagon R LXI LPG BSIV',
#  'Polo Petrol Highline 1.2L',
#  'Creta 1.6 SX Plus Diesel',
#  'XF Diesel',
#  'Compass 2.0 Limited 4X4',
#  'Rover Range Rover Evoque 2.0 TD4 HSE Dynamic',
#  'Baleno Alpha Diesel',
#  'Ciaz ZDi SHVS',
#  'SX4 Vxi BSIII',
#  'Elantra CRDi SX',
#  'Pajero Sport 4X4',
#  'Ameo 1.2 MPI Comfortline',
#  'Ritz VXi',
#  'Verna CRDi SX',
#  'Swift Dzire Tour LDI',
#  'KUV 100 mFALCON D75 K6',
#  'Innova Crysta 2.4 ZX MT',
#  'Baleno Delta 1.2',
#  'Jazz VX Diesel',
#  'i20 1.2 Asta',
#  'i20 Sportz Diesel',
#  'New C-Class C 220d Avantgarde Edition C',
#  'Xcent 1.2 Kappa Base',
#  'Grand i10 AT Asta',
#  'Alto 800 VXI',
#  'Sail Hatchback 1.2 LS',
#  'C-Class Progressive C 220d',
#  'Superb Elegance 1.8 TSI AT',
#  'A4 2.0 TDI',
#  'Innova 2.5 G (Diesel) 7 Seater BS IV',
#  'CLA 200 CDI Sport',
#  'i10 Era',
#  'Swift Dzire VXi',
#  'Rapid 1.5 TDI AT Ambition',
#  'Ritz VDi',
#  'Accent GLS 1.6',
#  'Amaze SX i-VTEC',
#  'Wagon R LXI',
#  'Polo Diesel Comfortline 1.2L',
#  'Endeavour 2.2 Trend AT 4X2',
#  'i20 1.2 Sportz',
#  'Beat Diesel PS',
#  'Civic 2010-2013 1.8 V MT',
#  'Wagon R VXI BS IV',
#  'Rapid 1.6 MPI Ambition Plus',
#  'Baleno Vxi - BSIII',
#  'EcoSport 1.5 TDCi Titanium',
#  'Accent GLE',
#  '5 Series 520d Luxury Line',
#  'Alto K10 2010-2014 VXI',
#  'Q3 2012-2015 2.0 TDI Quattro Premium Plus',
#  'Wagon R LXI DUO BSIII',
#  'Corolla H4',
#  'XC60 D5',
#  'Jazz 1.5 VX i DTEC',
#  'Ciaz 1.3 Alpha',
#  'Swift VXI BSIV',
#  'New C-Class C 220 CDI Avantgarde',
#  'Wagon R VXI Minor',
#  'A Class A180 Sport',
#  'Santro Xing GL',
#  'Swift Dzire AMT ZDI',
#  'Grand i10 AT Asta',
#  'Sunny 2011-2014 XV Special Edition',
#  ...]

# %% [markdown]
# # geeting unique values in models of cars

# %%
x = np.array(Model) 
y = (np.unique(x))

# %%
len(y)
# Out:
# 1876

# %% [markdown]
# # Entering car model name in dataset

# %%
data['Model'] = Model

# %%
data.head(10)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# 5       LPG       Manual      First  21.1 km/kg   814 CC   55.2 bhp    5.0
# 6    Diesel       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0
# 7    Diesel    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp    8.0
# 8    Diesel       Manual      First  20.54 kmpl  1598 CC  103.6 bhp    5.0
# 9    Diesel       Manual     Second   22.3 kmpl  1248 CC     74 bhp    5.0
#
#    Price  cleanEngine  cleanPower  cleanMileage  carCompany  \
# 0   1.75        998.0       58.16         26.60      Maruti
# 1  12.50       1582.0      126.20         19.67     Hyundai
# 2   4.50       1199.0       88.70         18.20       Honda
# 3   6.00       1248.0       88.76         20.77      Maruti
# 4  17.74       1968.0      140.80         15.20        Audi
# 5   2.35        814.0       55.20         21.10     Hyundai
# 6   3.50       1461.0       63.10         23.08      Nissan
# 7  17.50       2755.0      171.50         11.36      Toyota
# 8   5.20       1598.0      103.60         20.54  Volkswagen
# 9   1.95       1248.0       74.00         22.30        Tata
#
#                         Model
# 0             Wagon R LXI CNG
# 1    Creta 1.6 CRDi SX Option
# 2                      Jazz V
# 3                  Ertiga VDI
# 4  A4 New 2.0 TDI Multitronic
# 5     EON LPG Era Plus Option
# 6             Micra Diesel XV
# 7  Innova Crysta 2.8 GX AT 8S
# 8    Vento Diesel Comfortline
# 9   Indica Vista Quadrajet LS

# %% [markdown]
# # Dropping multiple useless columns like name, mileage, power and engine

# %%
data.drop(['Name', 'Mileage', 'Engine', 'Power'], axis = 1)
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0         Mumbai  2010              72000       CNG       Manual
# 1           Pune  2015              41000    Diesel       Manual
# 2        Chennai  2011              46000    Petrol       Manual
# 3        Chennai  2012              87000    Diesel       Manual
# 4     Coimbatore  2013              40670    Diesel    Automatic
# 5      Hyderabad  2012              75000       LPG       Manual
# 6         Jaipur  2013              86999    Diesel       Manual
# 7         Mumbai  2016              36000    Diesel    Automatic
# 8           Pune  2013              64430    Diesel       Manual
# 9        Chennai  2012              65932    Diesel       Manual
# 10         Kochi  2018              25692    Petrol       Manual
# 11       Kolkata  2012              60000    Petrol    Automatic
# 12        Jaipur  2015              64424    Diesel       Manual
# 13         Delhi  2014              72000    Diesel    Automatic
# 14          Pune  2012              85000    Diesel    Automatic
# 15         Delhi  2014             110000    Diesel       Manual
# 16         Kochi  2016              58950    Diesel       Manual
# 17        Jaipur  2017              25000    Diesel       Manual
# 18         Kochi  2014              77469    Diesel       Manual
# 19     Bangalore  2014              78500    Diesel    Automatic
# 20         Kochi  2014              32982    Diesel    Automatic
# 21     Bangalore  2015              55392    Diesel       Manual
# 22        Mumbai  2015              55985    Petrol    Automatic
# 23       Kolkata  2010              45807    Petrol       Manual
# 24       Kolkata  2010              33000    Petrol    Automatic
# 25        Mumbai  2012              51920    Petrol       Manual
# 26     Hyderabad  2012              54000    Diesel       Manual
# 27     Hyderabad  2013              54000    Petrol       Manual
# 28         Kochi  2018              37430    Petrol       Manual
# 29        Mumbai  2007             262000    Diesel       Manual
# ...          ...   ...                ...       ...          ...
# 5989  Coimbatore  2013              58629    Diesel    Automatic
# 5990        Pune  2008              86000    Diesel       Manual
# 5991   Hyderabad  2012              68238    Diesel       Manual
# 5992      Mumbai  2011              42036    Petrol    Automatic
# 5993      Mumbai  2014              55619    Petrol       Manual
# 5994        Pune  2009              60000    Petrol       Manual
# 5995        Pune  2015              30000    Diesel       Manual
# 5996       Kochi  2016              31150    Diesel    Automatic
# 5997      Jaipur  2010              70000       LPG       Manual
# 5998        Pune  2010              70290    Petrol       Manual
# 5999     Chennai  2016              10000    Petrol       Manual
# 6000   Bangalore  2014              68010    Petrol       Manual
# 6001       Kochi  2013              91903    Diesel    Automatic
# 6002      Mumbai  2011              38000    Petrol       Manual
# 6003   Bangalore  2015              67600    Petrol       Manual
# 6004  Coimbatore  2007              66800    Petrol       Manual
# 6005        Pune  2016              37208    Diesel       Manual
# 6006      Mumbai  2009             102002    Diesel    Automatic
# 6007       Delhi  2011              68000    Diesel       Manual
# 6008   Hyderabad  2013              40000    Diesel    Automatic
# 6009      Mumbai  2015              33500    Petrol    Automatic
# 6010       Delhi  2013              33746    Petrol       Manual
# 6011   Hyderabad  2009              53000    Petrol    Automatic
# 6012  Coimbatore  2011              45004    Diesel       Manual
# 6013  Coimbatore  2015              70602    Diesel       Manual
# 6014       Delhi  2014              27365    Diesel       Manual
# 6015      Jaipur  2015             100000    Diesel       Manual
# 6016      Jaipur  2012              55000    Diesel       Manual
# 6017     Kolkata  2013              46000    Petrol       Manual
# 6018   Hyderabad  2011              47000    Diesel       Manual
#
#           Owner_Type  Seats  Price  cleanEngine  cleanPower  cleanMileage  \
# 0              First    5.0   1.75        998.0       58.16         26.60
# 1              First    5.0  12.50       1582.0      126.20         19.67
# 2              First    5.0   4.50       1199.0       88.70         18.20
# 3              First    7.0   6.00       1248.0       88.76         20.77
# 4             Second    5.0  17.74       1968.0      140.80         15.20
# 5              First    5.0   2.35        814.0       55.20         21.10
# 6              First    5.0   3.50       1461.0       63.10         23.08
# 7              First    8.0  17.50       2755.0      171.50         11.36
# 8              First    5.0   5.20       1598.0      103.60         20.54
# 9             Second    5.0   1.95       1248.0       74.00         22.30
# 10             First    5.0   9.95       1462.0      103.25         21.56
# 11             First    5.0   4.49       1497.0      116.30         16.80
# 12             First    5.0   5.60       1248.0       74.00         25.20
# 13             First    5.0  27.00       2179.0      187.70         12.70
# 14            Second    5.0  17.50       2179.0      115.00          0.00
# 15             First    7.0  15.00       2477.0      175.56         13.50
# 16             First    5.0   5.40       1498.0       98.60         25.80
# 17             First    5.0   5.99       1248.0       74.00         28.40
# 18             First    5.0   6.34       1461.0       83.80         20.45
# 19             First    5.0  28.00       2143.0      167.62         14.84
# 20             First    5.0  18.55       1995.0      190.00         22.69
# 21            Second    5.0   8.25       1248.0       88.50         23.65
# 22             First    5.0  23.50       1984.0      177.01         13.53
# 23             First    5.0   1.87       1197.0       80.00         18.50
# 24             First    5.0   2.85       1598.0      103.60         14.40
# 25             First    5.0   4.25       1497.0      116.30         16.80
# 26             First    5.0   4.25       1461.0       63.10         23.08
# 27            Second    5.0   2.75        998.0       67.10         20.92
# 28             First    5.0   9.90       1199.0       88.70         17.50
# 29    Fourth & Above    7.0   4.00       2494.0      102.00         12.80
# ...              ...    ...    ...          ...         ...           ...
# 5989          Second    5.0  16.52       1968.0      187.74         18.25
# 5990           Third    7.0   0.60       2179.0      138.00         13.93
# 5991           First    5.0   4.80       1248.0       74.00         22.90
# 5992           First    5.0   6.25       1798.0      157.75         13.70
# 5993           First    5.0   8.30       1797.0      147.50         16.30
# 5994           Third    5.0   3.25       1497.0      118.00         17.00
# 5995           First    5.0   7.75       1461.0       83.80         19.87
# 5996           First    5.0  30.54       2179.0      187.70         16.36
# 5997           First    5.0   2.27        998.0       58.20         26.20
# 5998          Second    5.0   2.96       1198.0       73.90         17.24
# 5999           First    5.0   4.00       1193.0       88.70         17.57
# 6000          Second    5.0   5.25       1197.0       82.85         18.50
# 6001           First    5.0  17.56       1968.0      174.33         17.68
# 6002           First    5.0   3.25       1598.0      103.50         16.09
# 6003           First    5.0   4.00        998.0       67.04         23.10
# 6004           First    5.0   2.20       1341.0       83.00         15.30
# 6005           First    5.0   7.43       1248.0       88.50         24.30
# 6006           First    5.0  10.75       2987.0      224.34          8.70
# 6007           First    5.0   2.75       1248.0       73.90         19.30
# 6008          Second    4.0  45.00       2967.0      300.00         17.85
# 6009           First    5.0  19.75       2494.0      158.20         19.16
# 6010           First    5.0   3.20       1198.0       86.80         18.50
# 6011           First    5.0   4.75       3597.0      262.60          0.00
# 6012           First    7.0   9.48       2494.0      102.00         12.80
# 6013           First    5.0   4.83       1498.0       98.60         25.80
# 6014           First    5.0   4.75       1248.0       74.00         28.40
# 6015           First    5.0   4.00       1120.0       71.00         24.40
# 6016          Second    8.0   2.90       2498.0      112.00         14.00
# 6017           First    5.0   2.65        998.0       67.10         18.90
# 6018           First    5.0   2.50        936.0       57.60         25.44
#
#          carCompany                               Model
# 0            Maruti                     Wagon R LXI CNG
# 1           Hyundai            Creta 1.6 CRDi SX Option
# 2             Honda                              Jazz V
# 3            Maruti                          Ertiga VDI
# 4              Audi          A4 New 2.0 TDI Multitronic
# 5           Hyundai             EON LPG Era Plus Option
# 6            Nissan                     Micra Diesel XV
# 7            Toyota          Innova Crysta 2.8 GX AT 8S
# 8        Volkswagen            Vento Diesel Comfortline
# 9              Tata           Indica Vista Quadrajet LS
# 10           Maruti                           Ciaz Zeta
# 11            Honda               City 1.5 V AT Sunroof
# 12           Maruti                      Swift VDI BSIV
# 13             Land         Rover Range Rover 2.2L Pure
# 14             Land           Rover Freelander 2 TD4 SE
# 15       Mitsubishi                    Pajero Sport 4X4
# 16            Honda                     Amaze S i-Dtech
# 17           Maruti                      Swift DDiS VDI
# 18          Renault         Duster 85PS Diesel RxL Plus
# 19    Mercedes-Benz  New C-Class C 220 CDI BE Avantgare
# 20              BMW                       3 Series 320d
# 21           Maruti              S Cross DDiS 200 Alpha
# 22             Audi     A6 2011-2015 35 TFSI Technology
# 23          Hyundai                       i20 1.2 Magna
# 24       Volkswagen            Vento Petrol Highline AT
# 25            Honda              City Corporate Edition
# 26           Nissan                     Micra Diesel XV
# 27           Maruti              Alto K10 2010-2014 VXI
# 28            Honda                       WRV i-VTEC VX
# 29           Toyota        Innova 2.5 V Diesel 7-seater
# ...             ...                                 ...
# 5989           Audi              A4 35 TDI Premium Plus
# 5990           Tata         New Safari DICOR 2.2 VX 4x2
# 5991         Maruti                           Swift VDI
# 5992          Skoda          Superb Elegance 1.8 TSI AT
# 5993        Hyundai                          Elantra SX
# 5994          Honda                       City 1.5 E MT
# 5995        Renault      Duster 85PS Diesel RxL Explore
# 5996         Jaguar                 XF 2.2 Litre Luxury
# 5997         Maruti                     Wagon R Duo Lxi
# 5998     Volkswagen     Polo IPL II 1.2 Petrol Highline
# 5999           Tata                    Bolt Revotron XT
# 6000        Hyundai                      i20 Sportz 1.2
# 6001           Audi                A6 2011-2015 2.0 TDI
# 6002     Volkswagen                  Vento 1.6 Highline
# 6003         Maruti                         Celerio VXI
# 6004        Hyundai                            Getz GLE
# 6005         Maruti                   Vitara Brezza VDi
# 6006  Mercedes-Benz                  M-Class ML 320 CDI
# 6007         Maruti                Swift Dzire Vdi BSIV
# 6008        Porsche                     Panamera Diesel
# 6009         Toyota                        Camry Hybrid
# 6010          Honda                      Brio 1.2 VX MT
# 6011          Skoda                   Superb 3.6 V6 FSI
# 6012         Toyota        Innova 2.5 V Diesel 7-seater
# 6013          Honda                     Amaze VX i-DTEC
# 6014         Maruti                           Swift VDI
# 6015        Hyundai                    Xcent 1.1 CRDi S
# 6016       Mahindra                        Xylo D4 BSIV
# 6017         Maruti                         Wagon R VXI
# 6018      Chevrolet                         Beat Diesel
#
# [6019 rows x 13 columns]

# %% [markdown]
# # Checking number of unique Locations

# %%
uniqueLocations = data.Location.unique()

# %%
uniqueLocations.size
# Out:
# 11

# %% [markdown]
# # Performing EDA

# %%
plt.rcParams["figure.figsize"] = [30,10]

# %% [markdown]
# # 1. Which car company produces maximum cars

# %%
sns.countplot(x = "carCompany" , data = data)

# %% [markdown]
# # 2. Which location gives maximum price of cars

# %%
plt.title('Location VS Price of car')
sns.barplot(data['Location'], data['Price'])

# %% [markdown]
# # 3. Price of cars according to owner type

# %%
plt.title('Owner Type VS Price of car')
sns.barplot(data['Owner_Type'], data['Price'])

# %% [markdown]
# # Location wise distribution of owner_type of cars

# %%
g = sns.catplot(x="Location", y="Price", hue="Owner_Type", data=data,kind="bar")
g.fig.set_figwidth(20)
g.fig.set_figheight(10)

# %% [markdown]
# # Above graphs shows that Cars which of Third Owner type get maximum value on selling at Coimbatore and Delhi and least value at Jaipur and kochi

# %% [markdown]
# # 4. Car Company wise distribution of owner type of cars

# %%
g = sns.catplot(x="carCompany", y="Price", hue="Owner_Type", data=data,kind="bar")
g.fig.set_figwidth(40)
g.fig.set_figheight(20)

# %% [markdown]
# # Above graph shows only maruti, hyundai, toyota and ford cars go for Fourth and above owner type
#
# # Price of Audi, Porche and Lamborgini are high even for third owner type

# %% [markdown]
# # 5. Location wise variation in price of cars belonging to different compnay

# %%
g = sns.catplot(x="carCompany", y="Price", hue="Location", data=data,kind="bar")
g.fig.set_figwidth(80)
g.fig.set_figheight(20)

# %% [markdown]
# For maruti maximum price is at: Coimbatore and kochi
# For Hyundai maximum price is at: Coimbatore, Kochi and Bangalore
# For Honda maximum price is at: Coimbatore, Hyderabad and Kochi
# For Audi maximum price is at: Coimbatore, Bangalore
# For Nissan maximum price is at: Coimabatore, Bangalore and Kochi
# For Toyota maximum price is at: Coimbatore and Kochi

# %% [markdown]
# # 6. Company wise distribution of owner_type of cars and thier count

# %%
plt.rcParams["figure.figsize"] = [30,10]
g = sns.countplot(x="carCompany", data = data, hue = 'Owner_Type')

# %% [markdown]
# # Number of unique values in each column

# %%
data.nunique(axis=0)
# Out:
# Name                 1876
# Location               11
# Year                   22
# Kilometers_Driven    3093
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               442
# Engine                146
# Power                 372
# Seats                   9
# Price                1373
# cleanEngine           147
# cleanPower            370
# cleanMileage          431
# carCompany             31
# Model                1876
# dtype: int64

# %% [markdown]
# # Description of each kind of numeric column

# %%
data.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#               Year Kilometers_Driven        Seats        Price  cleanEngine  \
# count  6019.000000       6019.000000  6019.000000  6019.000000  6019.000000
# mean   2013.358199      58738.380296     5.255856     9.479468  1621.276447
# std       3.269742      91268.843206     0.850975    11.187917   599.553865
# min    1998.000000        171.000000     0.000000     0.440000    72.000000
# 25%    2011.000000      34000.000000     5.000000     3.500000  1198.000000
# 50%    2014.000000      53000.000000     5.000000     5.640000  1493.000000
# 75%    2016.000000      73000.000000     5.000000     9.950000  1969.000000
# max    2019.000000    6500000.000000    10.000000   160.000000  5998.000000
#
#         cleanPower cleanMileage
# count  6019.000000  6019.000000
# mean    113.204915    18.134961
# std      53.231914     4.581528
# min      34.200000     0.000000
# 25%      78.000000    15.170000
# 50%      98.600000    18.150000
# 75%     138.030000    21.100000
# max     560.000000    33.540000

# %%
from sklearn import preprocessing

# %% [markdown]
# <h2>Feature extraction</h2>

# %%
#features 
x = data[['Kilometers_Driven','Year','Seats','cleanEngine','cleanPower','cleanMileage']]
x.head(5)
# Out:
#    Kilometers_Driven  Year  Seats  cleanEngine  cleanPower  cleanMileage
# 0              72000  2010    5.0        998.0       58.16         26.60
# 1              41000  2015    5.0       1582.0      126.20         19.67
# 2              46000  2011    5.0       1199.0       88.70         18.20
# 3              87000  2012    7.0       1248.0       88.76         20.77
# 4              40670  2013    5.0       1968.0      140.80         15.20

# %%
y = data['Price']

# %% [markdown]
# <h2>Applying train-test-split</h2>

# %%
#applying train-test-split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=4)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)
# Out:
# Train set: (4514, 6) (4514,)
# Test set: (1505, 6) (1505,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
lr = LinearRegression().fit(x_train,y_train)
lr
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# -1981.354382257443
# [-1.46454266e-05  9.81739481e-01 -7.83305981e-01  2.51362555e-03
#   1.37219941e-01 -2.51425954e-02]

# %%
yhat = lr.predict(x_test)
yhat
# Out:
# array([13.9628241 ,  6.63859226,  1.08611152, ..., 11.32286693,
#         3.15191527,  5.86807222])

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, yhat))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, yhat))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, yhat)))
print('Accuracy:',lr.score(x_test,y_test))
# Out:
# Mean Absolute Error: 4.034067440466599
# Mean Squared Error: 50.500888698400416
# Root Mean Squared Error: 7.10639773010211
# Accuracy: 0.5993747664542786

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': yhat})
df1=df.head(10)

# %%
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print (f' Train Score is {lr.score(x_train, y_train)}')
# Out:
#  Train Score is 0.6851361514256656

# %%
#loading test data set
path ="D:\Data_Test.csv" 
test_df = pd.read_csv(path)
test_df.head(10)
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
# 5                     Mahindra XUV500 W8 2WD  Coimbatore  2016
# 6        Toyota Fortuner 4x2 AT TRD Sportivo        Pune  2015
# 7                       Hyundai EON Era Plus      Jaipur  2013
# 8                        Honda City 1.5 S MT      Mumbai  2011
# 9                     Mahindra XUV500 W6 2WD  Coimbatore  2015
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
# 5              85609    Diesel       Manual     Second    16.0 kmpl  2179 CC
# 6              59000    Diesel    Automatic      First   12.55 kmpl  2982 CC
# 7              65000    Petrol       Manual      First    21.1 kmpl   814 CC
# 8              66000    Petrol       Manual     Second    17.0 kmpl  1497 CC
# 9              54684    Diesel       Manual      First    15.1 kmpl  2179 CC
#
#        Power  Seats
# 0   58.2 bhp    4.0
# 1   47.3 bhp    5.0
# 2  147.8 bhp    7.0
# 3   null bhp    5.0
# 4  82.85 bhp    5.0
# 5    140 bhp    7.0
# 6  168.7 bhp    7.0
# 7   55.2 bhp    5.0
# 8    118 bhp    5.0
# 9    140 bhp    7.0

# %%
print (f' Train Score is {lr.score(x_train, y_train)}')
print (f' Test Score is {lr.score(x_test, y_test)}')
# Out:
#  Train Score is 0.6851361514256656
#  Test Score is 0.5993747664542786

# %%
#applying gradient boosting
from sklearn.ensemble import GradientBoostingRegressor
xTrain, xTest, yTrain, yTest = train_test_split(x, y,train_size = 0.80)

gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=10, random_state=0, loss='huber')
gb = gb.fit(xTrain, yTrain)
y_pred = gb.predict(xTest)
y_pred
print("Accuracy:{0:.3f}".format(gb.score(xTest,yTest)))
# Out:
# Accuracy:0.907

# %%
print (f' Train Score is {lr.score(xTrain, yTrain)}')
print (f' Test Score is {lr.score(xTest, yTest)}')
# Out:
#  Train Score is 0.6538774745915024
#  Test Score is 0.6996237819992819

# %%
df = pd.DataFrame({'Actual': yTest, 'Predicted': y_pred})
df1=df.head(10)

# %%
df1.head(10)
# Out:
#       Actual  Predicted
# 1323    4.50   4.519433
# 2378    6.68   9.012875
# 4666    5.35   5.454466
# 30      7.75   5.827684
# 2395   20.50  18.072922
# 1284    1.99   3.209232
# 5595   24.75  18.306131
# 3817    6.95   6.576074
# 5207    4.41   4.124430
# 5343    3.00   3.068320

# %% [markdown]
# <h1>Pridicted price vs Actual price</h1>

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
df_predicted_price = pd.DataFrame({'Predicted Prices': y_pred})
df_predicted_price.head(10)
# Out:
#    Predicted Prices
# 0          4.519433
# 1          9.012875
# 2          5.454466
# 3          5.827684
# 4         18.072922
# 5          3.209232
# 6         18.306131
# 7          6.576074
# 8          4.124430
# 9          3.068320

# %% [markdown]
# <h1> Final data set which is displaying the predicted prices of used cars</h1>

# %%
result = pd.concat(frame)
result = pd.concat([test_df,df_predicted_price], axis=1, sort=False)
result.head(10)
# Out:
# C:\Users\hersh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
# 5                     Mahindra XUV500 W8 2WD  Coimbatore  2016
# 6        Toyota Fortuner 4x2 AT TRD Sportivo        Pune  2015
# 7                       Hyundai EON Era Plus      Jaipur  2013
# 8                        Honda City 1.5 S MT      Mumbai  2011
# 9                     Mahindra XUV500 W6 2WD  Coimbatore  2015
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
# 5              85609    Diesel       Manual     Second    16.0 kmpl  2179 CC
# 6              59000    Diesel    Automatic      First   12.55 kmpl  2982 CC
# 7              65000    Petrol       Manual      First    21.1 kmpl   814 CC
# 8              66000    Petrol       Manual     Second    17.0 kmpl  1497 CC
# 9              54684    Diesel       Manual      First    15.1 kmpl  2179 CC
#
#        Power  Seats  Predicted Prices
# 0   58.2 bhp    4.0          4.519433
# 1   47.3 bhp    5.0          9.012875
# 2  147.8 bhp    7.0          5.454466
# 3   null bhp    5.0          5.827684
# 4  82.85 bhp    5.0         18.072922
# 5    140 bhp    7.0          3.209232
# 6  168.7 bhp    7.0         18.306131
# 7   55.2 bhp    5.0          6.576074
# 8    118 bhp    5.0          4.124430
# 9    140 bhp    7.0          3.068320
